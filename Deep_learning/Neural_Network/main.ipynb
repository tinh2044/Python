# %%
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
X = load_iris().data
y = load_iris().target
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# y_train = np.argmax(y_train, axis=1)
X_train= X_train.reshape(X_train.shape[0], -1)
X_test= X_test.reshape(X_test.shape[0], -1)

X_train = X_train /255
X_test = X_test / 255


a = np.zeros((y_train.shape[0], np.max(y_train)+1))
a[np.arange(len(a)), y_train] = 1
y_train = a

# %%
class ActivationFunction:
    def __init__(self):
        self.dictionary = {}
        self._create_dict()
        
    @staticmethod
    def sigmoid(z):
        z = np.copy(z)
        return 1.0/(1.0+np.exp(-z))
        
    def sigmoid_prime(self,z):
        z = np.copy(z)
        
        return self.sigmoid(z)*(1 - self.sigmoid(z))
    
    @staticmethod
    def relu(z):
        return np.maximum(0, z)
    
    @staticmethod
    def relu_prime(z):
        new_z = np.copy(z)
        new_z[ new_z > 0] = 1
        new_z[ new_z< 0] = 0
        return new_z
    
    @staticmethod
    def tanh(z):
        z = np.copy(z)
        
        return ((np.exp(z) - np.exp(-z))/
                (np.exp(z) + np.exp(-z)))
    
    def tanh_prime(self, z):
        z = np.copy(z)
        
        return 1- self.tanh(z)**2
    @staticmethod
    def soft_max(z):
        
        return np.exp(z)/ np.sum(np.exp(z))
    @staticmethod
    def soft_max_prime(z):
        
        return np.exp(z)/ np.sum(np.exp(z))

            
    
    
    def _create_dict(self):
        name = ['relu', 'sigmoid', 'tanh']
        child = [
            (self.relu, self.relu_prime),
            (self.sigmoid, self.sigmoid_prime),
            (self.tanh, self.tanh_prime),
        ]
        
        self.dictionary = dict(zip(name, child))

# %%
class Layer:
    def __init__(self, input_shape, output_shape,lr, n, activation="relu"):
        self.input_shape = input_shape
        self.output_shape = output_shape
        self.lr = lr
        self.n = n
        self.input = None
        self.output = None
        self.activation_type = activation
        self.activation = None
        self.activation_prime = None
        self.activation_func = ActivationFunction().dictionary
        self._choice_activation_func()
        
        self.weights = np.random.rand(self.input_shape, self.output_shape)
        self.biases = np.random.rand(1, self.output_shape)
        
    def forward_propagation(self, input):
        self.input = self.activation(input)
        
        if self.input.ndim ==1:
            self.input = self.input.reshape(1, -1)

        self.output = self.input@self.weights + self.biases
    

        return self.output
    def backward_propagation(self, prev_err):
        layer_err =  prev_err*self.activation(self.output)@self.weights.T
        
        d_weights = self.input.T@prev_err
        
        self.weights -= (self.lr*d_weights)
        self.biases -= (self.lr*np.sum(prev_err, axis=0))
        
        return layer_err
        
    def _choice_activation_func(self):
        activation_func = self.activation_func[self.activation_type]
        self.activation = activation_func[0]
        self.activation_prime = activation_func[1]

class LastLayer(Layer):
        
    def forward_propagation(self, input):
        self.input = np.array(input)
        self.output = self.input
        
        return np.exp(self.output) / np.sum(np.exp(self.output))
    
    def backward_propagation(self, prev_err):
            
        
        return self.activation_prime(self.input)*prev_err

# %%
class NetWork:
    def __init__(self, activation, layer: list[int], lr, epochs):
        self.activation = activation
        self.layers: list[Layer] = []
        self.num_layers = layer
        self.lr = lr
        self.epochs = epochs
        self.n = None
        
        
    def _create_layers(self):
        for i in range(len(self.num_layers)-1):
            layer = Layer(input_shape=self.num_layers[i],
                          output_shape=self.num_layers[i+1],
                          lr=self.lr,
                          activation=self.activation,
                          n=self.n
                          )
            self.layers.append(layer)
        last_layer = LastLayer(
            input_shape= self.num_layers[-1],
            output_shape= 1,
            lr= self.lr,
            activation=self.activation,
                          n=self.n
            
            
        )
        self.layers.append(last_layer)

    def fit(self, X,y):
        self.n = len(X)
        self._create_layers()
        for i in range(self.epochs):
            error_epoch = 0
            
            output = np.copy(X)
            for layer in self.layers:
                output = layer.forward_propagation(output)
            
            error_epoch += self.loss(y, output)
            
            error_prime = self.loss_prime(y, output)
            for layer in reversed(self.layers):
                error_prime = layer.backward_propagation(error_prime)
            
            error_epoch = np.sum(error_epoch) / self.n
            print(f'At epoch : {i} has error : {error_epoch}')
            
                   
    @staticmethod
    def loss(y_true, y_pred):
        return -np.sum(y_true * np.log(y_pred+ 1e-8))
    @staticmethod
    def loss_prime(y_true, y_pred):
        return y_true-y_pred
    
    def predict(self, X):
        res = []
        for x in X:
            output = x
            
            for layer in self.layers:
                output = layer.forward_propagation(output)
            res.extend(output)
        res = np.argmax(res, axis=1)
        return res

# %%
net = NetWork(activation='sigmoid', layer=[784, 16,16,  10], epochs=1000, lr=0.03)
net.fit(X_train[:100],y_train[:100])
# Out:
# At epoch : 0 has error : 7.540114230875877
# At epoch : 1 has error : 7.541321017447178
# At epoch : 2 has error : 7.54253289685025
# At epoch : 3 has error : 7.543749908840249
# At epoch : 4 has error : 7.544972093647385
# At epoch : 5 has error : 7.546199491984623
# At epoch : 6 has error : 7.547432145055583
# At epoch : 7 has error : 7.5486700945625715
# At epoch : 8 has error : 7.549913382714808
# At epoch : 9 has error : 7.551162052236798
# At epoch : 10 has error : 7.552416146376904
# At epoch : 11 has error : 7.553675708916078
# At epoch : 12 has error : 7.554940784176796
# At epoch : 13 has error : 7.556211417032166
# At epoch : 14 has error : 7.557487652915248
# At epoch : 15 has error : 7.558769537828554
# At epoch : 16 has error : 7.560057118353773
# At epoch : 17 has error : 7.561350441661691
# At epoch : 18 has error : 7.562649555522333
# At epoch : 19 has error : 7.563954508315336
# At epoch : 20 has error : 7.565265349040524
# At epoch : 21 has error : 7.566582127328741
# At epoch : 22 has error : 7.567904893452919
# At epoch : 23 has error : 7.569233698339378
# At epoch : 24 has error : 7.5705685935794005
# At epoch : 25 has error : 7.571909631441046
# At epoch : 26 has error : 7.573256864881239
# At epoch : 27 has error : 7.57461034755814
# At epoch : 28 has error : 7.575970133843793
# At epoch : 29 has error : 7.577336278837047
# At epoch : 30 has error : 7.578708838376799
# At epoch : 31 has error : 7.580087869055535
# At epoch : 32 has error : 7.581473428233171
# At epoch : 33 has error : 7.582865574051237
# At epoch : 34 has error : 7.5842643654473845
# At epoch : 35 has error : 7.585669862170236
# At epoch : 36 has error : 7.587082124794588
# At epoch : 37 has error : 7.58850121473697
# At epoch : 38 has error : 7.589927194271592
# At epoch : 39 has error : 7.591360126546647
# At epoch : 40 has error : 7.59280007560104
# At epoch : 41 has error : 7.5942471063815
# At epoch : 42 has error : 7.595701284760118
# At epoch : 43 has error : 7.597162677552312
# At epoch : 44 has error : 7.598631352535246
# At epoch : 45 has error : 7.600107378466691
# At epoch : 46 has error : 7.60159082510436
# At epoch : 47 has error : 7.603081763225735
# At epoch : 48 has error : 7.6045802646483835
# At epoch : 49 has error : 7.6060864022507975
# At epoch : 50 has error : 7.607600249993754
# At epoch : 51 has error : 7.609121882942232
# At epoch : 52 has error : 7.610651377287886
# At epoch : 53 has error : 7.6121888103721
# At epoch : 54 has error : 7.613734260709646
# At epoch : 55 has error : 7.615287808012962
# At epoch : 56 has error : 7.616849533217062
# At epoch : 57 has error : 7.618419518505107
# At epoch : 58 has error : 7.619997847334657
# At epoch : 59 has error : 7.62158460446463
# At epoch : 60 has error : 7.623179875982966
# At epoch : 61 has error : 7.624783749335068
# At epoch : 62 has error : 7.626396313352991
# At epoch : 63 has error : 7.628017658285447
# At epoch : 64 has error : 7.629647875828619
# At epoch : 65 has error : 7.631287059157844
# At epoch : 66 has error : 7.6329353029601625
# At epoch : 67 has error : 7.634592703467789
# At epoch : 68 has error : 7.636259358492523
# At epoch : 69 has error : 7.63793536746113
# At epoch : 70 has error : 7.639620831451739
# At epoch : 71 has error : 7.641315853231268
# At epoch : 72 has error : 7.643020537293954
# At epoch : 73 has error : 7.644734989900964
# At epoch : 74 has error : 7.646459319121204
# At epoch : 75 has error : 7.648193634873298
# At epoch : 76 has error : 7.649938048968809
# At epoch : 77 has error : 7.651692675156762
# At epoch : 78 has error : 7.653457629169481
# At epoch : 79 has error : 7.655233028769827
# At epoch : 80 has error : 7.6570189937998325
# At epoch : 81 has error : 7.658815646230867
# At epoch : 82 has error : 7.660623110215297
# At epoch : 83 has error : 7.6624415121397735
# At epoch : 84 has error : 7.664270980680166
# At epoch : 85 has error : 7.666111646858201
# At epoch : 86 has error : 7.667963644099925
# At epoch : 87 has error : 7.669827108295972
# At epoch : 88 has error : 7.671702177863796
# At epoch : 89 has error : 7.673588993811885
# At epoch : 90 has error : 7.675487699806052
# At epoch : 91 has error : 7.677398442237907
# At epoch : 92 has error : 7.679321370295546
# At epoch : 93 has error : 7.681256636036605
# At epoch : 94 has error : 7.6832043944637265
# At epoch : 95 has error : 7.685164803602561
# At epoch : 96 has error : 7.687138024582409
# At epoch : 97 has error : 7.689124221719588
# At epoch : 98 has error : 7.691123562603684
# At epoch : 99 has error : 7.693136218186732
# At epoch : 100 has error : 7.695162362875546
# At epoch : 101 has error : 7.697202174627251
# At epoch : 102 has error : 7.69925583504819
# At epoch : 103 has error : 7.701323529496348
# At epoch : 104 has error : 7.703405447187443
# At epoch : 105 has error : 7.705501781304847
# At epoch : 106 has error : 7.7076127291135
# At epoch : 107 has error : 7.7097384920779914
# At epoch : 108 has error : 7.711879275985023
# At epoch : 109 has error : 7.7140352910704015
# At epoch : 110 has error : 7.716206752150822
# At epoch : 111 has error : 7.718393878760612
# At epoch : 112 has error : 7.72059689529371
# At epoch : 113 has error : 7.722816031151078
# At epoch : 114 has error : 7.725051520893854
# At epoch : 115 has error : 7.727303604402457
# At epoch : 116 has error : 7.729572527041996
# At epoch : 117 has error : 7.7318585398342154
# At epoch : 118 has error : 7.734161899636365
# At epoch : 119 has error : 7.736482869327272
# At epoch : 120 has error : 7.738821718001016
# At epoch : 121 has error : 7.741178721168573
# At epoch : 122 has error : 7.743554160967808
# At epoch : 123 has error : 7.745948326382273
# At epoch : 124 has error : 7.748361513469242
# At epoch : 125 has error : 7.750794025597485
# At epoch : 126 has error : 7.7532461736952305
# At epoch : 127 has error : 7.75571827650894
# At epoch : 128 has error : 7.758210660873389
# At epoch : 129 has error : 7.760723661993723
# At epoch : 130 has error : 7.763257623740093
# At epoch : 131 has error : 7.765812898955585
# At epoch : 132 has error : 7.768389849778179
# At epoch : 133 has error : 7.770988847977505
# At epoch : 134 has error : 7.773610275307235
# At epoch : 135 has error : 7.7762545238740355
# At epoch : 136 has error : 7.778921996523965
# At epoch : 137 has error : 7.781613107247406
# At epoch : 138 has error : 7.7843282816035755
# At epoch : 139 has error : 7.78706795716578
# At epoch : 140 has error : 7.789832583988686
# At epoch : 141 has error : 7.792622625098918
# At epoch : 142 has error : 7.795438557010422
# At epoch : 143 has error : 7.798280870266144
# At epoch : 144 has error : 7.801150070007646
# At epoch : 145 has error : 7.804046676574472
# At epoch : 146 has error : 7.806971226135134
# At epoch : 147 has error : 7.809924271351783
# At epoch : 148 has error : 7.812906382080733
# At epoch : 149 has error : 7.81591814611092
# At epoch : 150 has error : 7.818960169941293
# At epoch : 151 has error : 7.822033079590626
# At epoch : 152 has error : 7.8251375213890375
# At epoch : 153 has error : 7.8282741624382
# At epoch : 154 has error : 7.831443688863285
# At epoch : 155 has error : 7.834646790541221
# At epoch : 156 has error : 7.837884063375295
# At epoch : 157 has error : 7.841155405152369
# At epoch : 158 has error : 7.844456305636398
# At epoch : 159 has error : 7.847756408626448
# At epoch : 160 has error : 7.850917849868311
# At epoch : 161 has error : 7.853767449544523
# At epoch : 162 has error : 7.856721064292779
# At epoch : 163 has error : 7.8600611437050425
# At epoch : 164 has error : 7.863564064493996
# At epoch : 165 has error : 7.86708106133487
# At epoch : 166 has error : 7.870383964316419
# At epoch : 167 has error : 7.8731687233129035
# At epoch : 168 has error : 7.876103199896971
# At epoch : 169 has error : 7.879645628812853
# At epoch : 170 has error : 7.883439668539199
# At epoch : 171 has error : 7.887322268252601
# At epoch : 172 has error : 7.891263543511886
# At epoch : 173 has error : 7.895259656111884
# At epoch : 174 has error : 7.899308675039283
# At epoch : 175 has error : 7.903396635373199
# At epoch : 176 has error : 7.90745169071074
# At epoch : 177 has error : 7.911276930995496
# At epoch : 178 has error : 7.915001598694694
# At epoch : 179 has error : 7.919156859564119
# At epoch : 180 has error : 7.9233590443714546
# At epoch : 181 has error : 7.926850659333499
# At epoch : 182 has error : 7.9299704584427015
# At epoch : 183 has error : 7.9339683785930255
# At epoch : 184 has error : 7.937288985651114
# At epoch : 185 has error : 7.937176324958646
# At epoch : 186 has error : 7.93367607068881
# At epoch : 187 has error : 7.933704012806417
# At epoch : 188 has error : 7.938387951766413
# At epoch : 189 has error : 7.944096424626816
# At epoch : 190 has error : 7.948939620305798
# At epoch : 191 has error : 7.949066830003974
# At epoch : 192 has error : 7.948100240991328
# At epoch : 193 has error : 7.953271958125051
# At epoch : 194 has error : 7.959146081446593
# At epoch : 195 has error : 7.957121643994679
# At epoch : 196 has error : 7.949159742727444
# At epoch : 197 has error : 7.944123957362646
# At epoch : 198 has error : 7.9252629576647085
# At epoch : 199 has error : 7.872468006101596
# At epoch : 200 has error : 7.780990237889287
# At epoch : 201 has error : 7.735249374811566
# At epoch : 202 has error : 7.74866576143233
# At epoch : 203 has error : 7.765783452216195
# At epoch : 204 has error : 7.784951259829328
# At epoch : 205 has error : 7.806676823106038
# At epoch : 206 has error : 7.825671646824548
# At epoch : 207 has error : 7.691076141116045
# At epoch : 208 has error : 7.704299158857853
# At epoch : 209 has error : 7.705308471643589
# At epoch : 210 has error : 7.728437440027361
# At epoch : 211 has error : 7.7830340198160695
# At epoch : 212 has error : 7.850649791242507
# At epoch : 213 has error : 7.9320668361322335
# At epoch : 214 has error : 8.027563910378902
# At epoch : 215 has error : 8.133134077655065
# At epoch : 216 has error : 8.239009749095857
# At epoch : 217 has error : 8.334718692340795
# At epoch : 218 has error : 8.415225204500603
# At epoch : 219 has error : 8.480949971447938
# At epoch : 220 has error : 8.53497958127128
# At epoch : 221 has error : 8.58044215620452
# At epoch : 222 has error : 8.619322483834152
# At epoch : 223 has error : 8.652742512970258
# At epoch : 224 has error : 8.681532703424073
# At epoch : 225 has error : 8.706447292903142
# At epoch : 226 has error : 8.728177540701292
# At epoch : 227 has error : 8.747354740678862
# At epoch : 228 has error : 8.764577537657742
# At epoch : 229 has error : 8.780450583123987
# At epoch : 230 has error : 8.795623917453716
# At epoch : 231 has error : 8.81082132872447
# At epoch : 232 has error : 8.826830244786647
# At epoch : 233 has error : 8.844395122587642
# At epoch : 234 has error : 8.863933750221317
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19544\817588615.py:9: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# At epoch : 235 has error : 8.885075729889618
# At epoch : 236 has error : 8.906323060264508
# At epoch : 237 has error : 8.925379148780003
# At epoch : 238 has error : 8.940131103247303
# At epoch : 239 has error : 8.949384582790493
# At epoch : 240 has error : 8.952833606712316
# At epoch : 241 has error : 8.950662812143598
# At epoch : 242 has error : 8.943223890148321
# At epoch : 243 has error : 8.930881347972974
# At epoch : 244 has error : 8.91397156065018
# At epoch : 245 has error : 8.892820197128902
# At epoch : 246 has error : 8.867791631218275
# At epoch : 247 has error : 8.839362180561192
# At epoch : 248 has error : 8.808214796319213
# At epoch : 249 has error : 8.775346264413205
# At epoch : 250 has error : 8.742154973659899
# At epoch : 251 has error : 8.71043603237589
# At epoch : 252 has error : 8.682174207411299
# At epoch : 253 has error : 8.659071553876563
# At epoch : 254 has error : 8.641959052941024
# At epoch : 255 has error : 8.630491113028079
# At epoch : 256 has error : 8.623414566731508
# At epoch : 257 has error : 8.619202679497839
# At epoch : 258 has error : 8.61657474392044
# At epoch : 259 has error : 8.614667698611038
# At epoch : 260 has error : 8.61294934938886
# At epoch : 261 has error : 8.611055781221872
# At epoch : 262 has error : 8.608676624140118
# At epoch : 263 has error : 8.605527553592943
# At epoch : 264 has error : 8.601389322603486
# At epoch : 265 has error : 8.596167996133408
# At epoch : 266 has error : 8.589937011045118
# At epoch : 267 has error : 8.582941848098296
# At epoch : 268 has error : 8.57556603521809
# At epoch : 269 has error : 8.568266688286924
# At epoch : 270 has error : 8.561491760437903
# At epoch : 271 has error : 8.55559420154981
# At epoch : 272 has error : 8.5507612308509
# At epoch : 273 has error : 8.546976667315077
# At epoch : 274 has error : 8.544026938164059
# At epoch : 275 has error : 8.541547561397003
# At epoch : 276 has error : 8.539093187128005
# At epoch : 277 has error : 8.536208679280783
# At epoch : 278 has error : 8.53248361056053
# At epoch : 279 has error : 8.527583135026882
# At epoch : 280 has error : 8.52125760569604
# At epoch : 281 has error : 8.513337885916009
# At epoch : 282 has error : 8.503723509206504
# At epoch : 283 has error : 8.492368883421154
# At epoch : 284 has error : 8.479270471418609
# At epoch : 285 has error : 8.464456175461988
# At epoch : 286 has error : 8.447977142871459
# At epoch : 287 has error : 8.429901728600383
# At epoch : 288 has error : 8.410311185610187
# At epoch : 289 has error : 8.38929664826295
# At epoch : 290 has error : 8.366957032872131
# At epoch : 291 has error : 8.343397554712439
# At epoch : 292 has error : 8.318728631267717
# At epoch : 293 has error : 8.293065000526555
# At epoch : 294 has error : 8.266524930348936
# At epoch : 295 has error : 8.239229432300219
# At epoch : 296 has error : 8.211301423297858
# At epoch : 297 has error : 8.182864802998436
# At epoch : 298 has error : 8.15404343550406
# At epoch : 299 has error : 8.124960041486567
# At epoch : 300 has error : 8.095735021475003
# At epoch : 301 has error : 8.066485242696057
# At epoch : 302 has error : 8.037322830157136
# At epoch : 303 has error : 8.008354007246727
# At epoch : 304 has error : 7.979678031767605
# At epoch : 305 has error : 7.951386270057006
# At epoch : 306 has error : 7.923561445070663
# At epoch : 307 has error : 7.896277084745351
# At epoch : 308 has error : 7.869597185611014
# At epoch : 309 has error : 7.84357609465035
# At epoch : 310 has error : 7.81825860094543
# At epoch : 311 has error : 7.793680218697812
# At epoch : 312 has error : 7.769867635481706
# At epoch : 313 has error : 7.746839294481809
# At epoch : 314 has error : 7.724606077039394
# At epoch : 315 has error : 7.703172051859619
# At epoch : 316 has error : 7.68253525929313
# At epoch : 317 has error : 7.662688502657611
# At epoch : 318 has error : 7.643620123046824
# At epoch : 319 has error : 7.625314738965934
# At epoch : 320 has error : 7.607753937001714
# At epoch : 321 has error : 7.590916904263371
# At epoch : 322 has error : 7.574780997304974
# At epoch : 323 has error : 7.5593222455545375
# At epoch : 324 has error : 7.544515789899059
# At epoch : 325 has error : 7.530336259039068
# At epoch : 326 has error : 7.516758087598383
# At epoch : 327 has error : 7.503755780842469
# At epoch : 328 has error : 7.491304131316685
# At epoch : 329 has error : 7.4793783928552795
# At epoch : 330 has error : 7.467954417316005
# At epoch : 331 has error : 7.457008759134838
# At epoch : 332 has error : 7.446518752428562
# At epoch : 333 has error : 7.436462564946039
# At epoch : 334 has error : 7.426819232716316
# At epoch : 335 has error : 7.417568678788824
# At epoch : 336 has error : 7.408691719024943
# At epoch : 337 has error : 7.400170057492468
# At epoch : 338 has error : 7.39198627364156
# At epoch : 339 has error : 7.384123803105333
# At epoch : 340 has error : 7.376566913671126
# At epoch : 341 has error : 7.369300677708254
# At epoch : 342 has error : 7.3623109421126
# At epoch : 343 has error : 7.355584296634753
# At epoch : 344 has error : 7.349108041293461
# At epoch : 345 has error : 7.342870153436673
# At epoch : 346 has error : 7.336859254895254
# At epoch : 347 has error : 7.331064579576758
# At epoch : 348 has error : 7.325475941765437
# At epoch : 349 has error : 7.320083705328022
# At epoch : 350 has error : 7.314878753969953
# At epoch : 351 has error : 7.3098524626423815
# At epoch : 352 has error : 7.304996670164375
# At epoch : 353 has error : 7.300303653095955
# At epoch : 354 has error : 7.2957661008750065
# At epoch : 355 has error : 7.291377092213102
# At epoch : 356 has error : 7.2871300727317045
# At epoch : 357 has error : 7.283018833809645
# At epoch : 358 has error : 7.279037492605131
# At epoch : 359 has error : 7.275180473210017
# At epoch : 360 has error : 7.271442488890276
# At epoch : 361 has error : 7.267818525364369
# At epoch : 362 has error : 7.264303825069876
# At epoch : 363 has error : 7.260893872368554
# At epoch : 364 has error : 7.257584379640273
# At epoch : 365 has error : 7.254371274217179
# At epoch : 366 has error : 7.251250686110703
# At epoch : 367 has error : 7.24821893648564
# At epoch : 368 has error : 7.245272526837213
# At epoch : 369 has error : 7.242408128829003
# At epoch : 370 has error : 7.23962257475154
# At epoch : 371 has error : 7.2369128485634135
# At epoch : 372 has error : 7.234276077478694
# At epoch : 373 has error : 7.231709524066571
# At epoch : 374 has error : 7.229210578830881
# At epoch : 375 has error : 7.226776753239257
# At epoch : 376 has error : 7.224405673173312
# At epoch : 377 has error : 7.222095072773121
# At epoch : 378 has error : 7.219842788650822
# At epoch : 379 has error : 7.217646754449827
# At epoch : 380 has error : 7.215504995727583
# At epoch : 381 has error : 7.213415625141261
# At epoch : 382 has error : 7.211376837917041
# At epoch : 383 has error : 7.2093869075850145
# At epoch : 384 has error : 7.207444181962782
# At epoch : 385 has error : 7.205547079372029
# At epoch : 386 has error : 7.203694085073355
# At epoch : 387 has error : 7.201883747905617
# At epoch : 388 has error : 7.200114677116954
# At epoch : 389 has error : 7.198385539375486
# At epoch : 390 has error : 7.196695055948523
# At epoch : 391 has error : 7.195042000039816
# At epoch : 392 has error : 7.193425194275078
# At epoch : 393 has error : 7.191843508326683
# At epoch : 394 has error : 7.190295856668988
# At epoch : 395 has error : 7.188781196456355
# At epoch : 396 has error : 7.187298525516391
# At epoch : 397 has error : 7.185846880451516
# At epoch : 398 has error : 7.184425334842292
# At epoch : 399 has error : 7.183032997546474
# At epoch : 400 has error : 7.181669011088101
# At epoch : 401 has error : 7.1803325501313
# At epoch : 402 has error : 7.179022820033801
# At epoch : 403 has error : 7.177739055475565
# At epoch : 404 has error : 7.176480519158113
# At epoch : 405 has error : 7.175246500570466
# At epoch : 406 has error : 7.174036314817938
# At epoch : 407 has error : 7.172849301510089
# At epoch : 408 has error : 7.171684823704586
# At epoch : 409 has error : 7.170542266903724
# At epoch : 410 has error : 7.169421038100725
# At epoch : 411 has error : 7.168320564872982
# At epoch : 412 has error : 7.167240294519679
# At epoch : 413 has error : 7.1661796932413395
# At epoch : 414 has error : 7.165138245358969
# At epoch : 415 has error : 7.164115452570684
# At epoch : 416 has error : 7.1631108332437705
# At epoch : 417 has error : 7.162123921740252
# At epoch : 418 has error : 7.161154267774216
# At epoch : 419 has error : 7.160201435799155
# At epoch : 420 has error : 7.159265004423787
# At epoch : 421 has error : 7.158344565854822
# At epoch : 422 has error : 7.157439725365278
# At epoch : 423 has error : 7.156550100787033
# At epoch : 424 has error : 7.1556753220263225
# At epoch : 425 has error : 7.154815030601075
# At epoch : 426 has error : 7.153968879198878
# At epoch : 427 has error : 7.153136531254618
# At epoch : 428 has error : 7.15231766054674
# At epoch : 429 has error : 7.151511950811224
# At epoch : 430 has error : 7.150719095372385
# At epoch : 431 has error : 7.149938796789669
# At epoch : 432 has error : 7.1491707665196556
# At epoch : 433 has error : 7.148414724592512
# At epoch : 434 has error : 7.147670399302216
# At epoch : 435 has error : 7.146937526909864
# At epoch : 436 has error : 7.146215851359442
# At epoch : 437 has error : 7.14550512400547
# At epoch : 438 has error : 7.144805103351935
# At epoch : 439 has error : 7.144115554801999
# At epoch : 440 has error : 7.143436250417978
# At epoch : 441 has error : 7.142766968691085
# At epoch : 442 has error : 7.142107494320511
# At epoch : 443 has error : 7.1414576180014055
# At epoch : 444 has error : 7.14081713622134
# At epoch : 445 has error : 7.140185851064871
# At epoch : 446 has error : 7.139563570025842
# At epoch : 447 has error : 7.138950105827064
# At epoch : 448 has error : 7.1383452762470485
# At epoch : 449 has error : 7.137748903953477
# At epoch : 450 has error : 7.137160816343115
# At epoch : 451 has error : 7.136580845387861
# At epoch : 452 has error : 7.136008827486712
# At epoch : 453 has error : 7.1354446033233145
# At epoch : 454 has error : 7.134888017728931
# At epoch : 455 has error : 7.134338919550537
# At epoch : 456 has error : 7.133797161523858
# At epoch : 457 has error : 7.133262600151105
# At epoch : 458 has error : 7.13273509558326
# At epoch : 459 has error : 7.13221451150665
# At epoch : 460 has error : 7.131700715033691
# At epoch : 461 has error : 7.131193576597602
# At epoch : 462 has error : 7.1306929698509
# At epoch : 463 has error : 7.130198771567577
# At epoch : 464 has error : 7.129710861548752
# At epoch : 465 has error : 7.129229122531688
# At epoch : 466 has error : 7.128753440102023
# At epoch : 467 has error : 7.12828370260909
# At epoch : 468 has error : 7.1278198010841995
# At epoch : 469 has error : 7.127361629161771
# At epoch : 470 has error : 7.1269090830031905
# At epoch : 471 has error : 7.1264620612232905
# At epoch : 472 has error : 7.126020464819355
# At epoch : 473 has error : 7.125584197102532
# At epoch : 474 has error : 7.125153163631596
# At epoch : 475 has error : 7.124727272148913
# At epoch : 476 has error : 7.124306432518576
# At epoch : 477 has error : 7.123890556666616
# At epoch : 478 has error : 7.12347955852316
# At epoch : 479 has error : 7.123073353966543
# At epoch : 480 has error : 7.122671860769235
# At epoch : 481 has error : 7.122274998545547
# At epoch : 482 has error : 7.12188268870103
# At epoch : 483 has error : 7.121494854383521
# At epoch : 484 has error : 7.1211114204357635
# At epoch : 485 has error : 7.120732313349558
# At epoch : 486 has error : 7.1203574612213565
# At epoch : 487 has error : 7.119986793709281
# At epoch : 488 has error : 7.119620241991501
# At epoch : 489 has error : 7.119257738725914
# At epoch : 490 has error : 7.1188992180110935
# At epoch : 491 has error : 7.1185446153484495
# At epoch : 492 has error : 7.118193867605563
# At epoch : 493 has error : 7.117846912980656
# At epoch : 494 has error : 7.117503690968147
# At epoch : 495 has error : 7.11716414232526
# At epoch : 496 has error : 7.116828209039653
# At epoch : 497 has error : 7.116495834298025
# At epoch : 498 has error : 7.116166962455671
# At epoch : 499 has error : 7.115841539006936
# At epoch : 500 has error : 7.115519510556576
# At epoch : 501 has error : 7.115200824791952
# At epoch : 502 has error : 7.114885430456049
# At epoch : 503 has error : 7.114573277321296
# At epoch : 504 has error : 7.114264316164147
# At epoch : 505 has error : 7.113958498740406
# At epoch : 506 has error : 7.11365577776127
# At epoch : 507 has error : 7.113356106870064
# At epoch : 508 has error : 7.1130594406196455
# At epoch : 509 has error : 7.112765734450452
# At epoch : 510 has error : 7.112474944669184
# At epoch : 511 has error : 7.112187028428091
# At epoch : 512 has error : 7.111901943704831
# At epoch : 513 has error : 7.11161964928292
# At epoch : 514 has error : 7.111340104732705
# At epoch : 515 has error : 7.111063270392893
# At epoch : 516 has error : 7.110789107352564
# At epoch : 517 has error : 7.110517577433704
# At epoch : 518 has error : 7.110248643174227
# At epoch : 519 has error : 7.109982267811424
# At epoch : 520 has error : 7.109718415265906
# At epoch : 521 has error : 7.109457050125963
# At epoch : 522 has error : 7.109198137632342
# At epoch : 523 has error : 7.1089416436634565
# At epoch : 524 has error : 7.108687534720969
# At epoch : 525 has error : 7.108435777915776
# At epoch : 526 has error : 7.108186340954364
# At epoch : 527 has error : 7.107939192125508
# At epoch : 528 has error : 7.107694300287358
# At epoch : 529 has error : 7.107451634854829
# At epoch : 530 has error : 7.107211165787346
# At epoch : 531 has error : 7.106972863576888
# At epoch : 532 has error : 7.106736699236367
# At epoch : 533 has error : 7.106502644288282
# At epoch : 534 has error : 7.10627067075369
# At epoch : 535 has error : 7.106040751141438
# At epoch : 536 has error : 7.105812858437682
# At epoch : 537 has error : 7.105586966095676
# At epoch : 538 has error : 7.105363048025809
# At epoch : 539 has error : 7.1051410785859
# At epoch : 540 has error : 7.104921032571744
# At epoch : 541 has error : 7.104702885207871
# At epoch : 542 has error : 7.104486612138573
# At epoch : 543 has error : 7.104272189419121
# At epoch : 544 has error : 7.104059593507206
# At epoch : 545 has error : 7.10384880125461
# At epoch : 546 has error : 7.103639789899062
# At epoch : 547 has error : 7.103432537056299
# At epoch : 548 has error : 7.10322702071232
# At epoch : 549 has error : 7.103023219215836
# At epoch : 550 has error : 7.102821111270889
# At epoch : 551 has error : 7.10262067592966
# At epoch : 552 has error : 7.102421892585442
# At epoch : 553 has error : 7.10222474096579
# At epoch : 554 has error : 7.1020292011258235
# At epoch : 555 has error : 7.101835253441697
# At epoch : 556 has error : 7.101642878604223
# At epoch : 557 has error : 7.1014520576126365
# At epoch : 558 has error : 7.101262771768522
# At epoch : 559 has error : 7.101075002669866
# At epoch : 560 has error : 7.100888732205259
# At epoch : 561 has error : 7.1007039425482334
# At epoch : 562 has error : 7.1005206161517185
# At epoch : 563 has error : 7.100338735742639
# At epoch : 564 has error : 7.100158284316628
# At epoch : 565 has error : 7.09997924513287
# At epoch : 566 has error : 7.0998016017090455
# At epoch : 567 has error : 7.09962533781641
# At epoch : 568 has error : 7.09945043747497
# At epoch : 569 has error : 7.099276884948771
# At epoch : 570 has error : 7.099104664741301
# At epoch : 571 has error : 7.098933761590981
# At epoch : 572 has error : 7.098764160466764
# At epoch : 573 has error : 7.09859584656384
# At epoch : 574 has error : 7.098428805299421
# At epoch : 575 has error : 7.098263022308625
# At epoch : 576 has error : 7.09809848344046
# At epoch : 577 has error : 7.09793517475388
# At epoch : 578 has error : 7.097773082513938
# At epoch : 579 has error : 7.09761219318802
# At epoch : 580 has error : 7.0974524934421535
# At epoch : 581 has error : 7.097293970137422
# At epoch : 582 has error : 7.097136610326412
# At epoch : 583 has error : 7.096980401249782
# At epoch : 584 has error : 7.096825330332871
# At epoch : 585 has error : 7.096671385182406
# At epoch : 586 has error : 7.096518553583252
# At epoch : 587 has error : 7.096366823495259
# At epoch : 588 has error : 7.0962161830501564
# At epoch : 589 has error : 7.096066620548511
# At epoch : 590 has error : 7.09591812445677
# At epoch : 591 has error : 7.095770683404344
# At epoch : 592 has error : 7.095624286180756
# At epoch : 593 has error : 7.09547892173286
# At epoch : 594 has error : 7.095334579162102
# At epoch : 595 has error : 7.095191247721852
# At epoch : 596 has error : 7.095048916814776
# At epoch : 597 has error : 7.0949075759902795
# At epoch : 598 has error : 7.0947672149419825
# At epoch : 599 has error : 7.094627823505264
# At epoch : 600 has error : 7.094489391654849
# At epoch : 601 has error : 7.094351909502438
# At epoch : 602 has error : 7.094215367294403
# At epoch : 603 has error : 7.094079755409501
# At epoch : 604 has error : 7.093945064356665
# At epoch : 605 has error : 7.093811284772815
# At epoch : 606 has error : 7.093678407420723
# At epoch : 607 has error : 7.093546423186923
# At epoch : 608 has error : 7.093415323079653
# At epoch : 609 has error : 7.093285098226847
# At epoch : 610 has error : 7.09315573987416
# At epoch : 611 has error : 7.093027239383032
# At epoch : 612 has error : 7.092899588228795
# At epoch : 613 has error : 7.092772777998814
# At epoch : 614 has error : 7.092646800390662
# At epoch : 615 has error : 7.09252164721033
# At epoch : 616 has error : 7.092397310370481
# At epoch : 617 has error : 7.0922737818887205
# At epoch : 618 has error : 7.0921510538859165
# At epoch : 619 has error : 7.0920291185845405
# At epoch : 620 has error : 7.091907968307052
# At epoch : 621 has error : 7.091787595474296
# At epoch : 622 has error : 7.09166799260395
# At epoch : 623 has error : 7.091549152308984
# At epoch : 624 has error : 7.091431067296163
# At epoch : 625 has error : 7.091313730364568
# At epoch : 626 has error : 7.09119713440415
# At epoch : 627 has error : 7.091081272394307
# At epoch : 628 has error : 7.09096613740249
# At epoch : 629 has error : 7.0908517225828405
# At epoch : 630 has error : 7.090738021174834
# At epoch : 631 has error : 7.090625026501978
# At epoch : 632 has error : 7.090512731970502
# At epoch : 633 has error : 7.0904011310681
# At epoch : 634 has error : 7.090290217362674
# At epoch : 635 has error : 7.090179984501113
# At epoch : 636 has error : 7.090070426208092
# At epoch : 637 has error : 7.089961536284888
# At epoch : 638 has error : 7.089853308608229
# At epoch : 639 has error : 7.089745737129142
# At epoch : 640 has error : 7.089638815871842
# At epoch : 641 has error : 7.089532538932642
# At epoch : 642 has error : 7.089426900478861
# At epoch : 643 has error : 7.089321894747774
# At epoch : 644 has error : 7.089217516045566
# At epoch : 645 has error : 7.089113758746317
# At epoch : 646 has error : 7.08901061729099
# At epoch : 647 has error : 7.088908086186453
# At epoch : 648 has error : 7.0888061600045
# At epoch : 649 has error : 7.0887048333809135
# At epoch : 650 has error : 7.088604101014514
# At epoch : 651 has error : 7.08850395766625
# At epoch : 652 has error : 7.088404398158293
# At epoch : 653 has error : 7.08830541737315
# At epoch : 654 has error : 7.08820701025279
# At epoch : 655 has error : 7.088109171797788
# At epoch : 656 has error : 7.088011897066484
# At epoch : 657 has error : 7.087915181174152
# At epoch : 658 has error : 7.08781901929219
# At epoch : 659 has error : 7.087723406647311
# At epoch : 660 has error : 7.0876283385207755
# At epoch : 661 has error : 7.087533810247593
# At epoch : 662 has error : 7.087439817215784
# At epoch : 663 has error : 7.08734635486562
# At epoch : 664 has error : 7.087253418688892
# At epoch : 665 has error : 7.087161004228194
# At epoch : 666 has error : 7.0870691070762
# At epoch : 667 has error : 7.086977722874978
# At epoch : 668 has error : 7.086886847315295
# At epoch : 669 has error : 7.086796476135945
# At epoch : 670 has error : 7.086706605123086
# At epoch : 671 has error : 7.086617230109582
# At epoch : 672 has error : 7.086528346974367
# At epoch : 673 has error : 7.0864399516417995
# At epoch : 674 has error : 7.086352040081062
# At epoch : 675 has error : 7.086264608305528
# At epoch : 676 has error : 7.086177652372173
# At epoch : 677 has error : 7.086091168380978
# At epoch : 678 has error : 7.086005152474354
# At epoch : 679 has error : 7.085919600836553
# At epoch : 680 has error : 7.085834509693118
# At epoch : 681 has error : 7.0857498753103325
# At epoch : 682 has error : 7.085665693994655
# At epoch : 683 has error : 7.085581962092201
# At epoch : 684 has error : 7.0854986759882035
# At epoch : 685 has error : 7.0854158321065
# At epoch : 686 has error : 7.085333426909014
# At epoch : 687 has error : 7.085251456895256
# At epoch : 688 has error : 7.0851699186018235
# At epoch : 689 has error : 7.085088808601915
# At epoch : 690 has error : 7.085008123504854
# At epoch : 691 has error : 7.084927859955608
# At epoch : 692 has error : 7.084848014634325
# At epoch : 693 has error : 7.084768584255882
# At epoch : 694 has error : 7.084689565569428
# At epoch : 695 has error : 7.084610955357935
# At epoch : 696 has error : 7.084532750437768
# At epoch : 697 has error : 7.084454947658262
# At epoch : 698 has error : 7.084377543901273
# At epoch : 699 has error : 7.084300536080787
# At epoch : 700 has error : 7.084223921142498
# At epoch : 701 has error : 7.084147696063396
# At epoch : 702 has error : 7.084071857851383
# At epoch : 703 has error : 7.083996403544868
# At epoch : 704 has error : 7.083921330212388
# At epoch : 705 has error : 7.083846634952224
# At epoch : 706 has error : 7.083772314892026
# At epoch : 707 has error : 7.083698367188444
# At epoch : 708 has error : 7.083624789026764
# At epoch : 709 has error : 7.083551577620551
# At epoch : 710 has error : 7.083478730211294
# At epoch : 711 has error : 7.083406244068053
# At epoch : 712 has error : 7.083334116487135
# At epoch : 713 has error : 7.083262344791731
# At epoch : 714 has error : 7.0831909263316
# At epoch : 715 has error : 7.083119858482741
# At epoch : 716 has error : 7.083049138647061
# At epoch : 717 has error : 7.082978764252065
# At epoch : 718 has error : 7.082908732750537
# At epoch : 719 has error : 7.082839041620239
# At epoch : 720 has error : 7.082769688363594
# At epoch : 721 has error : 7.0827006705074
# At epoch : 722 has error : 7.082631985602523
# At epoch : 723 has error : 7.082563631223617
# At epoch : 724 has error : 7.08249560496882
# At epoch : 725 has error : 7.082427904459491
# At epoch : 726 has error : 7.082360527339916
# At epoch : 727 has error : 7.08229347127704
# At epoch : 728 has error : 7.082226733960194
# At epoch : 729 has error : 7.082160313100831
# At epoch : 730 has error : 7.082094206432254
# At epoch : 731 has error : 7.082028411709368
# At epoch : 732 has error : 7.081962926708415
# At epoch : 733 has error : 7.0818977492267265
# At epoch : 734 has error : 7.0818328770824746
# At epoch : 735 has error : 7.081768308114424
# At epoch : 736 has error : 7.081704040181692
# At epoch : 737 has error : 7.081640071163508
# At epoch : 738 has error : 7.081576398958984
# At epoch : 739 has error : 7.081513021486878
# At epoch : 740 has error : 7.081449936685365
# At epoch : 741 has error : 7.0813871425118124
# At epoch : 742 has error : 7.081324636942563
# At epoch : 743 has error : 7.081262417972706
# At epoch : 744 has error : 7.081200483615868
# At epoch : 745 has error : 7.081138831903998
# At epoch : 746 has error : 7.081077460887161
# At epoch : 747 has error : 7.081016368633317
# At epoch : 748 has error : 7.080955553228136
# At epoch : 749 has error : 7.080895012774781
# At epoch : 750 has error : 7.080834745393713
# At epoch : 751 has error : 7.080774749222498
# At epoch : 752 has error : 7.080715022415617
# At epoch : 753 has error : 7.080655563144258
# At epoch : 754 has error : 7.080596369596146
# At epoch : 755 has error : 7.0805374399753465
# At epoch : 756 has error : 7.0804787725020875
# At epoch : 757 has error : 7.080420365412576
# At epoch : 758 has error : 7.080362216958821
# At epoch : 759 has error : 7.080304325408451
# At epoch : 760 has error : 7.08024668904455
# At epoch : 761 has error : 7.08018930616548
# At epoch : 762 has error : 7.080132175084715
# At epoch : 763 has error : 7.0800752941306655
# At epoch : 764 has error : 7.080018661646529
# At epoch : 765 has error : 7.07996227599011
# At epoch : 766 has error : 7.079906135533674
# At epoch : 767 has error : 7.079850238663784
# At epoch : 768 has error : 7.079794583781136
# At epoch : 769 has error : 7.079739169300417
# At epoch : 770 has error : 7.079683993650149
# At epoch : 771 has error : 7.079629055272535
# At epoch : 772 has error : 7.079574352623313
# At epoch : 773 has error : 7.07951988417161
# At epoch : 774 has error : 7.079465648399799
# At epoch : 775 has error : 7.0794116438033505
# At epoch : 776 has error : 7.0793578688907015
# At epoch : 777 has error : 7.079304322183103
# At epoch : 778 has error : 7.079251002214498
# At epoch : 779 has error : 7.079197907531373
# At epoch : 780 has error : 7.079145036692632
# At epoch : 781 has error : 7.079092388269459
# At epoch : 782 has error : 7.079039960845198
# At epoch : 783 has error : 7.078987753015208
# At epoch : 784 has error : 7.078935763386749
# At epoch : 785 has error : 7.078883990578854
# At epoch : 786 has error : 7.078832433222201
# At epoch : 787 has error : 7.078781089958992
# At epoch : 788 has error : 7.0787299594428355
# At epoch : 789 has error : 7.078679040338627
# At epoch : 790 has error : 7.078628331322423
# At epoch : 791 has error : 7.078577831081334
# At epoch : 792 has error : 7.078527538313408
# At epoch : 793 has error : 7.078477451727515
# At epoch : 794 has error : 7.078427570043229
# At epoch : 795 has error : 7.078377891990735
# At epoch : 796 has error : 7.0783284163107005
# At epoch : 797 has error : 7.078279141754175
# At epoch : 798 has error : 7.078230067082486
# At epoch : 799 has error : 7.078181191067132
# At epoch : 800 has error : 7.0781325124896775
# At epoch : 801 has error : 7.07808403014165
# At epoch : 802 has error : 7.078035742824435
# At epoch : 803 has error : 7.07798764934919
# At epoch : 804 has error : 7.077939748536726
# At epoch : 805 has error : 7.0778920392174225
# At epoch : 806 has error : 7.077844520231126
# At epoch : 807 has error : 7.077797190427057
# At epoch : 808 has error : 7.077750048663713
# At epoch : 809 has error : 7.07770309380878
# At epoch : 810 has error : 7.077656324739029
# At epoch : 811 has error : 7.077609740340242
# At epoch : 812 has error : 7.07756333950711
# At epoch : 813 has error : 7.077517121143144
# At epoch : 814 has error : 7.077471084160595
# At epoch : 815 has error : 7.077425227480362
# At epoch : 816 has error : 7.0773795500319014
# At epoch : 817 has error : 7.077334050753157
# At epoch : 818 has error : 7.077288728590459
# At epoch : 819 has error : 7.077243582498457
# At epoch : 820 has error : 7.077198611440024
# At epoch : 821 has error : 7.077153814386186
# At epoch : 822 has error : 7.077109190316041
# At epoch : 823 has error : 7.07706473821667
# At epoch : 824 has error : 7.0770204570830755
# At epoch : 825 has error : 7.07697634591809
# At epoch : 826 has error : 7.0769324037323065
# At epoch : 827 has error : 7.076888629544007
# At epoch : 828 has error : 7.076845022379075
# At epoch : 829 has error : 7.076801581270939
# At epoch : 830 has error : 7.0767583052604826
# At epoch : 831 has error : 7.076715193395989
# At epoch : 832 has error : 7.07667224473306
# At epoch : 833 has error : 7.076629458334544
# At epoch : 834 has error : 7.076586833270472
# At epoch : 835 has error : 7.076544368617993
# At epoch : 836 has error : 7.076502063461296
# At epoch : 837 has error : 7.076459916891546
# At epoch : 838 has error : 7.0764179280068245
# At epoch : 839 has error : 7.076376095912052
# At epoch : 840 has error : 7.07633441971894
# At epoch : 841 has error : 7.076292898545905
# At epoch : 842 has error : 7.076251531518028
# At epoch : 843 has error : 7.076210317766973
# At epoch : 844 has error : 7.07616925643094
# At epoch : 845 has error : 7.076128346654588
# At epoch : 846 has error : 7.0760875875889955
# At epoch : 847 has error : 7.076046978391576
# At epoch : 848 has error : 7.0760065182260385
# At epoch : 849 has error : 7.075966206262321
# At epoch : 850 has error : 7.075926041676532
# At epoch : 851 has error : 7.075886023650898
# At epoch : 852 has error : 7.075846151373696
# At epoch : 853 has error : 7.075806424039211
# At epoch : 854 has error : 7.075766840847677
# At epoch : 855 has error : 7.075727401005213
# At epoch : 856 has error : 7.07568810372378
# At epoch : 857 has error : 7.075648948221124
# At epoch : 858 has error : 7.07560993372072
# At epoch : 859 has error : 7.075571059451724
# At epoch : 860 has error : 7.075532324648916
# At epoch : 861 has error : 7.075493728552658
# At epoch : 862 has error : 7.075455270408828
# At epoch : 863 has error : 7.075416949468787
# At epoch : 864 has error : 7.075378764989317
# At epoch : 865 has error : 7.075340716232581
# At epoch : 866 has error : 7.075302802466065
# At epoch : 867 has error : 7.0752650229625385
# At epoch : 868 has error : 7.075227376999999
# At epoch : 869 has error : 7.075189863861635
# At epoch : 870 has error : 7.07515248283577
# At epoch : 871 has error : 7.075115233215822
# At epoch : 872 has error : 7.075078114300257
# At epoch : 873 has error : 7.075041125392541
# At epoch : 874 has error : 7.075004265801102
# At epoch : 875 has error : 7.07496753483928
# At epoch : 876 has error : 7.074930931825284
# At epoch : 877 has error : 7.074894456082152
# At epoch : 878 has error : 7.074858106937708
# At epoch : 879 has error : 7.074821883724517
# At epoch : 880 has error : 7.07478578577984
# At epoch : 881 has error : 7.0747498124456065
# At epoch : 882 has error : 7.074713963068358
# At epoch : 883 has error : 7.074678236999218
# At epoch : 884 has error : 7.074642633593844
# At epoch : 885 has error : 7.074607152212397
# At epoch : 886 has error : 7.07457179221949
# At epoch : 887 has error : 7.0745365529841635
# At epoch : 888 has error : 7.0745014338798375
# At epoch : 889 has error : 7.074466434284276
# At epoch : 890 has error : 7.074431553579547
# At epoch : 891 has error : 7.074396791151995
# At epoch : 892 has error : 7.074362146392187
# At epoch : 893 has error : 7.074327618694895
# At epoch : 894 has error : 7.074293207459045
# At epoch : 895 has error : 7.074258912087691
# At epoch : 896 has error : 7.074224731987974
# At epoch : 897 has error : 7.074190666571091
# At epoch : 898 has error : 7.074156715252254
# At epoch : 899 has error : 7.074122877450663
# At epoch : 900 has error : 7.074089152589474
# At epoch : 901 has error : 7.074055540095751
# At epoch : 902 has error : 7.07402203940045
# At epoch : 903 has error : 7.073988649938376
# At epoch : 904 has error : 7.073955371148152
# At epoch : 905 has error : 7.073922202472191
# At epoch : 906 has error : 7.073889143356656
# At epoch : 907 has error : 7.073856193251438
# At epoch : 908 has error : 7.07382335161012
# At epoch : 909 has error : 7.073790617889943
# At epoch : 910 has error : 7.073757991551779
# At epoch : 911 has error : 7.0737254720601035
# At epoch : 912 has error : 7.073693058882959
# At epoch : 913 has error : 7.073660751491931
# At epoch : 914 has error : 7.073628549362113
# At epoch : 915 has error : 7.073596451972082
# At epoch : 916 has error : 7.0735644588038715
# At epoch : 917 has error : 7.073532569342934
# At epoch : 918 has error : 7.073500783078121
# At epoch : 919 has error : 7.07346909950165
# At epoch : 920 has error : 7.073437518109083
# At epoch : 921 has error : 7.073406038399294
# At epoch : 922 has error : 7.073374659874441
# At epoch : 923 has error : 7.0733433820399405
# At epoch : 924 has error : 7.073312204404447
# At epoch : 925 has error : 7.073281126479814
# At epoch : 926 has error : 7.073250147781079
# At epoch : 927 has error : 7.07321926782643
# At epoch : 928 has error : 7.073188486137189
# At epoch : 929 has error : 7.073157802237779
# At epoch : 930 has error : 7.073127215655697
# At epoch : 931 has error : 7.073096725921496
# At epoch : 932 has error : 7.073066332568758
# At epoch : 933 has error : 7.073036035134069
# At epoch : 934 has error : 7.0730058331569925
# At epoch : 935 has error : 7.0729757261800525
# At epoch : 936 has error : 7.072945713748698
# At epoch : 937 has error : 7.072915795411295
# At epoch : 938 has error : 7.072885970719089
# At epoch : 939 has error : 7.0728562392261916
# At epoch : 940 has error : 7.07282660048955
# At epoch : 941 has error : 7.072797054068931
# At epoch : 942 has error : 7.072767599526897
# At epoch : 943 has error : 7.0727382364287825
# At epoch : 944 has error : 7.07270896434267
# At epoch : 945 has error : 7.072679782839374
# At epoch : 946 has error : 7.072650691492416
# At epoch : 947 has error : 7.072621689877999
# At epoch : 948 has error : 7.072592777574996
# At epoch : 949 has error : 7.0725639541649254
# At epoch : 950 has error : 7.07253521923192
# At epoch : 951 has error : 7.072506572362724
# At epoch : 952 has error : 7.072478013146661
# At epoch : 953 has error : 7.072449541175614
# At epoch : 954 has error : 7.072421156044013
# At epoch : 955 has error : 7.072392857348806
# At epoch : 956 has error : 7.072364644689446
# At epoch : 957 has error : 7.07233651766787
# At epoch : 958 has error : 7.072308475888475
# At epoch : 959 has error : 7.0722805189581095
# At epoch : 960 has error : 7.072252646486041
# At epoch : 961 has error : 7.072224858083952
# At epoch : 962 has error : 7.072197153365908
# At epoch : 963 has error : 7.0721695319483455
# At epoch : 964 has error : 7.072141993450059
# At epoch : 965 has error : 7.07211453749217
# At epoch : 966 has error : 7.07208716369812
# At epoch : 967 has error : 7.07205987169365
# At epoch : 968 has error : 7.072032661106782
# At epoch : 969 has error : 7.0720055315677985
# At epoch : 970 has error : 7.071978482709232
# At epoch : 971 has error : 7.071951514165847
# At epoch : 972 has error : 7.0719246255746135
# At epoch : 973 has error : 7.071897816574704
# At epoch : 974 has error : 7.071871086807466
# At epoch : 975 has error : 7.071844435916413
# At epoch : 976 has error : 7.071817863547202
# At epoch : 977 has error : 7.071791369347625
# At epoch : 978 has error : 7.071764952967581
# At epoch : 979 has error : 7.071738614059077
# At epoch : 980 has error : 7.071712352276195
# At epoch : 981 has error : 7.071686167275089
# At epoch : 982 has error : 7.071660058713961
# At epoch : 983 has error : 7.071634026253052
# At epoch : 984 has error : 7.071608069554625
# At epoch : 985 has error : 7.071582188282946
# At epoch : 986 has error : 7.0715563821042755
# At epoch : 987 has error : 7.071530650686852
# At epoch : 988 has error : 7.071504993700871
# At epoch : 989 has error : 7.071479410818478
# At epoch : 990 has error : 7.071453901713753
# At epoch : 991 has error : 7.071428466062693
# At epoch : 992 has error : 7.071403103543203
# At epoch : 993 has error : 7.071377813835072
# At epoch : 994 has error : 7.071352596619972
# At epoch : 995 has error : 7.071327451581437
# At epoch : 996 has error : 7.071302378404851
# At epoch : 997 has error : 7.07127737677743
# At epoch : 998 has error : 7.0712524463882165
# At epoch : 999 has error : 7.071227586928059

# %%
prediction = net.predict(X_test)
print(prediction)
print(y_test)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19544\817588615.py:9: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# [5 5 5 ... 5 5 5]
# [7 2 1 ... 4 5 6]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction)
# Out:
# 0.0892
