# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("./data.xlsx")
# data.head()

# %% [markdown]
# ### Basic

# %%
# PLot
y = "2*(x*x*x)-x-1"
value_y = []
value_x = np.arange(-10, 10, 0.1)

for x in value_x:
    value_y.append(eval(y , {"x" : x}))
plt.style.use('_mpl-gallery')
plt.plot(value_x, value_y)

# %%
# Scatter 
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(15, 80, len(x))
colors = np.random.uniform(15, 80, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=0, vmax=100)

# ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#        ylim=(0, 8), yticks=np.arange(1, 8))
# fig, ax = plt.subplot()

# %%
# Bar
plt.style.use('_mpl-gallery')

# make data:
np.random.seed(3)
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
# Out:
# array([4.75398951, 5.54073911, 3.45452369, 4.55413803, 6.46473477,
#        6.48146544, 2.62792655, 3.03621439])

# %%
# Stem
x = np.arange(10)
y = np.random.randint(10,size=10)
plt.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %%
# Step
plt.step(x,y)

# %%
y_1 = "x+1"
y_2 = "2*x-1"
value_x = 10*np.random.rand(10)
value_y_1 = []
value_y_2 = []
for i in x:
    value_y_1.append(eval(y_1, {"x":x}))
    value_y_2.append(eval(y_2, {"x":x}))
# plt.fill_between(value_x, value_y_1, value_y_2)
# value_y_1
value_x
# Out:
# array([4.88873245, 9.27936348, 7.876182  , 4.85094226, 4.55279361,
#        2.17985768, 1.77213381, 0.73623669, 8.92393188, 6.40176617])
